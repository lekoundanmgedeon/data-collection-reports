# %% [markdown]
# ## LEKOUNDA NGOLO Mardochet Gédéon
# ### COOP MSC | DATA SCIENCE
# #### ASSIGNEMENT 1 :  DATA COLLECTION
# ##### 20-11-2025

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2010_per_game.html'
# Scrape the data tables from 2010 to 2024 using pandas.read_html and clean the data

# %%
import pandas as pd
data = pd.read_html(url, header = 0)
len(data) # Let's check lenght of data of url
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1615414003.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 data = pd.read_html(url, header = 0)
#       3 len(data) # Let's check lenght of data of url
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1238         )
#    1239
# -> 1240     return _parse(
#    1241         flavor=flavor,
#    1242         io=io,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     981
#     982         try:
# --> 983             tables = p.parse_tables()
# ...

# %%
#Use a for loop to  collect data from 2000 to 2024
df= pd.DataFrame()
for year in range(2000, 2025):
  url_page = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
  print(url_page) # Test si 2000-2024
  data = pd.read_html(url_page) # [df_page]
  df_page = data[0]
  df_page['year'] = year
  df = pd.concat([df, df_page], axis =0).reset_index(drop = True)

# %%
# df dimension (just for checking, necessairly for  )
df.shape

# %%
# Display of df
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-366194626.py in <cell line: 0>()
#       1 # Display of df
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %%
# 1.1 Check for null values
print(df.isnull().any().sum())
# Out:
# 0

# %%
# 1.2 Check for null values
print(df.isnull().sum())
# Out:
# Rk           24
# Player        0
# Age          24
# Team         24
# Pos          24
# G            24
# GS           24
# MP           24
# FG           24
# FGA          24
# FG%          85
# 3P           24
# 3PA          24
# 3P%        2031
# 2P           24
# 2PA          24
# 2P%         155
# eFG%         85
# FT           24
# FTA          24
# FT%         740
# ORB          24
# DRB          24
# TRB          24
# AST          24
# STL          24
# BLK          24
# TOV          24
# PF           24
# PTS          24
# Awards    13020
# year          0
# dtype: int64

# %%
#2 Handle the non-values

# Replace by N/A for non numeric columns
df['Team'] = df['Team'].fillna("N/A")
df['Pos'] = df['Pos'].fillna("N/A")
df['Awards'] = df['Awards'].fillna("N/A")

# Replace all numeric (float and int) values by his mean
for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        df[col].fillna(df[col].mean(), inplace=True)

# df = df.fillna(df.mean(numeric_only=True)) # or this panda method do also well

# %%
#3. Check for duplicated value
print(df.duplicated().sum())

# %%
# 4. Handle for duplicated values
df = df.drop_duplicates()
print(df.duplicated().sum())
# Nothing to do here, because sum of duplicated values is 0
# Out:
# 0

# %%
#5. Check dtypes values
df.dtypes
# Out:
# Rk        float64
# Player     object
# Age       float64
# Team       object
# Pos        object
# G         float64
# GS        float64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# Awards     object
# year        int64
# dtype: object

# %%
# Exporter en CSV
df.to_csv("nba_stats_2000_2024_clean.csv", index=False)
